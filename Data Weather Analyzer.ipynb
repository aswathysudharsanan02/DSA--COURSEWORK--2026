# %%
# Weather Data Analyzer

# Taking number of days
n = int(input("Enter number of days: "))

# Lists to store data
temperatures = []
humidities = []

# Input temperature and humidity
for i in range(n):
    temp = float(input("Enter temperature for day " + str(i+1) + ": "))
    hum = float(input("Enter humidity for day " + str(i+1) + ": "))
    
    temperatures.append(temp)
    humidities.append(hum)

# Function to calculate average
def calculate_average(data):
    return sum(data) / len(data)

# Function to determine weather condition
def determine_weather(avg_temp, avg_humidity):
    if avg_temp > 30 and avg_humidity < 50:
        return "Sunny"
    elif avg_humidity > 70:
        return "Rainy"
    elif avg_temp < 20:
        return "Cold"
    else:
        return "Moderate"

# Function to display results
def display_results():
    avg_temp = calculate_average(temperatures)
    avg_humidity = calculate_average(humidities)
    condition = determine_weather(avg_temp, avg_humidity)

    print("\n--- Weather Report ---")
    print("Average Temperature:", avg_temp)
    print("Average Humidity:", avg_humidity)
    print("Weather Condition:", condition)

# Run the program
display_results()
# Out:
# Enter number of days:  3
# Enter temperature for day 1:  32
# Enter humidity for day 1:  45
# Enter temperature for day 2:  30
# Enter humidity for day 2:  50
# Enter temperature for day 3:  31
# Enter humidity for day 3:  40
# --- Weather Report ---
# Average Temperature: 31.0
# Average Humidity: 45.0
# Weather Condition: Sunny

# %%
# Weather Data Analyzer

# Taking number of days
n = int(input("Enter number of days: "))

# Lists to store data
temperatures = []
humidities = []

# Input temperature and humidity
for i in range(n):
    temp = float(input("Enter temperature for day " + str(i+1) + ": "))
    hum = float(input("Enter humidity for day " + str(i+1) + ": "))
    
    temperatures.append(temp)
    humidities.append(hum)

# Function to calculate average
def calculate_average(data):
    return sum(data) / len(data)

# Function to determine weather condition
def determine_weather(avg_temp, avg_humidity):
    if avg_temp > 30 and avg_humidity < 50:
        return "Sunny"
    elif avg_humidity > 70:
        return "Rainy"
    elif avg_temp < 20:
        return "Cold"
    else:
        return "Moderate"

# Function to display results
def display_results():
    avg_temp = calculate_average(temperatures)
    avg_humidity = calculate_average(humidities)
    condition = determine_weather(avg_temp, avg_humidity)

    print("\n--- Weather Report ---")
    print("Average Temperature:", avg_temp)
    print("Average Humidity:", avg_humidity)
    print("Weather Condition:", condition)

# Run the program
display_results()
# Out:
# Enter number of days:  3
# Enter temperature for day 1:  25
# Enter humidity for day 1:  80
# Enter temperature for day 2:  27
# Enter humidity for day 2:  75
# Enter temperature for day 3:  26
# Enter humidity for day 3:  78
# --- Weather Report ---
# Average Temperature: 26.0
# Average Humidity: 77.66666666666667
# Weather Condition: Rainy

# %%
# Weather Data Analyzer

# Taking number of days
n = int(input("Enter number of days: "))

# Lists to store data
temperatures = []
humidities = []

# Input temperature and humidity
for i in range(n):
    temp = float(input("Enter temperature for day " + str(i+1) + ": "))
    hum = float(input("Enter humidity for day " + str(i+1) + ": "))
    
    temperatures.append(temp)
    humidities.append(hum)

# Function to calculate average
def calculate_average(data):
    return sum(data) / len(data)

# Function to determine weather condition
def determine_weather(avg_temp, avg_humidity):
    if avg_temp > 30 and avg_humidity < 50:
        return "Sunny"
    elif avg_humidity > 70:
        return "Rainy"
    elif avg_temp < 20:
        return "Cold"
    else:
        return "Moderate"

# Function to display results
def display_results():
    avg_temp = calculate_average(temperatures)
    avg_humidity = calculate_average(humidities)
    condition = determine_weather(avg_temp, avg_humidity)

    print("\n--- Weather Report ---")
    print("Average Temperature:", avg_temp)
    print("Average Humidity:", avg_humidity)
    print("Weather Condition:", condition)

# Run the program
display_results()
# Out:
# Enter number of days:  2
# Enter temperature for day 1:  18
# Enter humidity for day 1:  60
# Enter temperature for day 2:  19
# Enter humidity for day 2:  65
# --- Weather Report ---
# Average Temperature: 18.5
# Average Humidity: 62.5
# Weather Condition: Cold

# %%
# Weather Data Analyzer

# Taking number of days
n = int(input("Enter number of days: "))

# Lists to store data
temperatures = []
humidities = []

# Input temperature and humidity
for i in range(n):
    temp = float(input("Enter temperature for day " + str(i+1) + ": "))
    hum = float(input("Enter humidity for day " + str(i+1) + ": "))
    
    temperatures.append(temp)
    humidities.append(hum)

# Function to calculate average
def calculate_average(data):
    return sum(data) / len(data)

# Function to determine weather condition
def determine_weather(avg_temp, avg_humidity):
    if avg_temp > 30 and avg_humidity < 50:
        return "Sunny"
    elif avg_humidity > 70:
        return "Rainy"
    elif avg_temp < 20:
        return "Cold"
    else:
        return "Moderate"

# Function to display results
def display_results():
    avg_temp = calculate_average(temperatures)
    avg_humidity = calculate_average(humidities)
    condition = determine_weather(avg_temp, avg_humidity)

    print("\n--- Weather Report ---")
    print("Average Temperature:", avg_temp)
    print("Average Humidity:", avg_humidity)
    print("Weather Condition:", condition)

# Run the program
display_results()
# Out:
# Enter number of days:  3
# Enter temperature for day 1:  26
# Enter humidity for day 1:  55
# Enter temperature for day 2:  28
# Enter humidity for day 2:  60
# Enter temperature for day 3:  27
# Enter humidity for day 3:  58
# --- Weather Report ---
# Average Temperature: 27.0
# Average Humidity: 57.666666666666664
# Weather Condition: Moderate
